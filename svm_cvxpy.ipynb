# %% [markdown]
# # SVM with CVXpy

# %%
import os

import cvxpy as cvx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC

# %%
# Retrieve dataset
# Kaggle PGA 2019 data: https://www.kaggle.com/bradklassen/pga-tour-20102018-data
data_dir = '/external-hd/rhombe/rheo-cc'
dataset = '2019_data.csv'

# %%
player_data = pd.read_csv(os.path.join(data_dir, dataset))

# %%
player_data.columns
# Out:
# Index(['Player Name', 'Date', 'Statistic', 'Variable', 'Value'], dtype='object')

# %%
player_data.Variable.unique()[:1000]
# Out:
# array(['Driving Distance - (ROUNDS)', 'Driving Distance - (AVG.)',
#        'Driving Distance - (TOTAL DISTANCE)',
#        'Driving Distance - (TOTAL DRIVES)',
#        'Driving Accuracy Percentage - (ROUNDS)',
#        'Driving Accuracy Percentage - (%)',
#        'Driving Accuracy Percentage - (FAIRWAYS HIT)',
#        'Driving Accuracy Percentage - (POSSIBLE FAIRWAYS)',
#        'Greens in Regulation Percentage - (ROUNDS)',
#        'Greens in Regulation Percentage - (%)',
#        'Greens in Regulation Percentage - (GREENS HIT)',
#        'Greens in Regulation Percentage - (# HOLES)',
#        'Greens in Regulation Percentage - (RELATIVE/PAR)',
#        'Putting Average - (ROUNDS)', 'Putting Average - (AVG)',
#        'Putting Average - (GIR PUTTS)', 'Putting Average - (GREENS HIT)',
#        'Putting Average - (BIRDIE CONVERSION)',
#        'Putting Average - (GIR RANK)', 'Par Breakers - (ROUNDS)',
#        'Par Breakers - (%)', 'Par Breakers - (# BIRDIES/EAGLES)',
# ...

# %%
player_data.Statistic.unique()
# Out:
# array(['Driving Distance', 'Driving Accuracy Percentage',
#        'Greens in Regulation Percentage', 'Putting Average',
#        'Par Breakers', 'Total Eagles', 'Total Birdies',
#        'Scoring Average (Actual)', 'Official Money',
#        'Sand Save Percentage', 'Par 3 Birdie or Better Leaders',
#        'Par 4 Birdie or Better Leaders', 'Par 5 Birdie or Better Leaders',
#        'Birdie or Better Conversion Percentage', 'Putts Per Round',
#        'Scoring Average', 'All-Around Ranking', 'Total Driving',
#        'Scrambling', 'Ryder Cup Points', 'PGA Championship Points',
#        'Putts made Distance', 'Top 10 Finishes', 'Non-member Earnings',
#        'Par 3 Scoring Average', 'Par 4 Scoring Average',
#        'Par 5 Scoring Average', "3-Putt Avoidance - 15-20'",
#        "3-Putt Avoidance - 20-25'", "3-Putt Avoidance > 25'",
#        'Current Par or Better Streak', "Rounds in the 60's",
#        'Money per Event Leaders', 'Eagles (Holes per)', 'Birdie Average',
# ...

# %%
len(player_data.Variable.unique())
# Out:
# 1486

# %%
# 374 Statistics for each player
# TODO: Manually select or run something like PCA?

# %%
# Show brief example in SKLearn

# %%
# SKLearn visualizations

# %%
# Formalism of SVM

# %%
# Using SKLearn result as a target, recreate in CVXPY

# %%
# CVXPY visualizations, etc
